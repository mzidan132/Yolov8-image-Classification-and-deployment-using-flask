# %%
from ultralytics import YOLO

model = YOLO('yolov8n-cls.pt')  # load a pretrained model (recommended for training)
#disease folder has train and val folder containing all the disease classes
model.train(data='C:/Users/mdzid/Documents/yolo/data/disease',
            epochs=20, imgsz=255)
# Out:
# Ultralytics YOLOv8.0.207  Python-3.11.3 torch-2.1.0+cpu CPU (Intel Core(TM) i5-8250U 1.60GHz)
# ...

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import cv2
import numpy as np


model = YOLO('./runs/classify/train2/weights/best.pt')  # load a custom model

img = cv2.imread("./Black Spot (58).jpg")
imS = cv2.resize(img, (255, 255)) 

results = model(imS,show=True)  # predict on an image

names_dict = results[0].names

probs = results[0].probs.data.tolist()

print(names_dict)
print(probs)
print(names_dict[np.argmax(probs)])

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 0: 256x256 Black Spot 0.99, Fresh Leaf 0.01, 22.3ms
# Speed: 6.5ms preprocess, 22.3ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 256)
# {0: 'Black Spot', 1: 'Fresh Leaf'}
# [0.9857043027877808, 0.014295701868832111]
# Black Spot
